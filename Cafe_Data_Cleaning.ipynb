# %% [markdown]
# # Cleaning Dirty Cafe Sales Dataset

# %%
#Import the operational laibries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import the cafe dataset

cafe = pd.read_csv('dirty_cafe_sales.csv')
cafe
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %% [markdown]
# ### Getting to know the data

# %%
cafe.shape
# Out:
# (10000, 8)

# %%
cafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
cafe.isna().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
cafe.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0       ERROR
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211   UNKNOWN        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867       NaN        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701     ERROR        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card       NaN       2023-03-31
# 6            ERROR  Takeaway       2023-10-06
# 7             Cash   UNKNOWN       2023-10-28
# 8              NaN  Takeaway       2023-07-28
# 9              NaN  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway            ERROR
# 12            Cash  In-store       2023-05-03
# 13             NaN  Takeaway       2023-06-01
# 14             NaN  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16             NaN       NaN       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash     ERROR       2023-03-25
# 19            Cash  Takeaway       2023-01-15

# %% [markdown]
# #### From observation, the data set has 10000 rows and 8 columns. Also, the supposed numeric columns are showing object as the data types.
#
# #### There are many missing values in all the columns except in the 'Transaction ID'.

# %% [markdown]
# #### There are some invalid items in the data set such as 'UNKNOWN', and 'ERROR' .

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Start by replacing the 'UKNOWN', NaN, and 'ERROR' with '0'

# %%
# starting with the column "Item"
cafe['Item'] = cafe['Item'].str.replace('UNKNOWN','0')
cafe['Item'] = cafe['Item'].str.replace('ERROR','0')
cafe['Item'] = cafe['Item'].fillna('0')

# %%
# starting with the column "Quantity"
cafe['Quantity'] = cafe['Quantity'].str.replace('UNKNOWN','0')
cafe['Quantity'] = cafe['Quantity'].str.replace('ERROR','0')
cafe['Quantity'] = cafe['Quantity'].fillna('0')

# %%
# starting with the column "Price Per Unit"
cafe['Price Per Unit'] = cafe['Price Per Unit'].str.replace('UNKNOWN','0')
cafe['Price Per Unit'] = cafe['Price Per Unit'].str.replace('ERROR','0')
cafe['Price Per Unit'] = cafe['Price Per Unit'].fillna('0')

# %%
# starting with the column "Total Spent"
cafe['Total Spent'] = cafe['Total Spent'].str.replace('UNKNOWN','0')
cafe['Total Spent'] = cafe['Total Spent'].str.replace('ERROR','0')
cafe['Total Spent'] = cafe['Total Spent'].fillna('0')

# %%
# starting with the column "Payment Method"
cafe['Payment Method'] = cafe['Payment Method'].str.replace('UNKNOWN','0')
cafe['Payment Method'] = cafe['Payment Method'].str.replace('ERROR','0')
cafe['Payment Method'] = cafe['Payment Method'].fillna('0')

# %%
# starting with the column "Location"
cafe['Location'] = cafe['Location'].str.replace('UNKNOWN','0')
cafe['Location'] = cafe['Location'].str.replace('ERROR','0')
cafe['Location'] = cafe['Location'].fillna('0')

# %%
# starting with the column "Transaction Date"
cafe['Transaction Date'] = cafe['Transaction Date'].str.replace('UNKNOWN','0')
cafe['Transaction Date'] = cafe['Transaction Date'].str.replace('ERROR','0')
cafe['Transaction Date'] = cafe['Transaction Date'].fillna('0')

# %%
cafe.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0           0
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211         0        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867         0        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701         0        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3                0         0       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card         0       2023-03-31
# 6                0  Takeaway       2023-10-06
# 7             Cash         0       2023-10-28
# 8                0  Takeaway       2023-07-28
# 9                0  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway                0
# 12            Cash  In-store       2023-05-03
# 13               0  Takeaway       2023-06-01
# 14               0  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16               0         0       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash         0       2023-03-25
# 19            Cash  Takeaway       2023-01-15

# %% [markdown]
# ## Populating the columns and changing the data types to the correct format

# %% [markdown]
# ### Working on the categorical columns

# %%
# find the count of the items in the "Item" column

cafe.Item.value_counts()

#finding the mode of the column
cafe.Item.mode()


# with 'Juice' being the most populated item in the column, the zero's will be replaced with 'Juice'
cafe['Item'] = cafe['Item'].str.replace('0','Juice')

# %%
# find the count of the items in the "Payment Method" column

cafe['Payment Method'].value_counts()

#finding the mode of the column
df = cafe[cafe['Payment Method'] > '0']
df['Payment Method'].value_counts()

# with 'Digital Wallet' being the most populated item in the column, the zero's will be replaced with 'Digital Wallet'
cafe['Payment Method'] = cafe['Payment Method'].str.replace('0','Digital Wallet')

# %%
# find the count of the items in the "Location" column

cafe.Location.value_counts()

#finding the mode of the column
df1 = cafe[cafe['Location'] > '0']
df1['Location'].value_counts()


# with 'Takeaway' being the most populated item in the column, the zero's will be replaced with 'Takeaway'
cafe['Location'] = cafe['Location'].str.replace('0','Takeaway')

# %%
cafe.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0           0
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211     Juice        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867     Juice        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701     Juice        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3   Digital Wallet  Takeaway       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card  Takeaway       2023-03-31
# 6   Digital Wallet  Takeaway       2023-10-06
# 7             Cash  Takeaway       2023-10-28
# 8   Digital Wallet  Takeaway       2023-07-28
# 9   Digital Wallet  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway                0
# 12            Cash  In-store       2023-05-03
# 13  Digital Wallet  Takeaway       2023-06-01
# 14  Digital Wallet  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16  Digital Wallet  Takeaway       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash  Takeaway       2023-03-25
# 19            Cash  Takeaway       2023-01-15

# %%
# Removing the zero's in the Transaction Date column
cafe = cafe[cafe['Transaction Date'] != '0']
cafe.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0           0
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211     Juice        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867     Juice        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701     Juice        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
# 20    TXN_3522028  Smoothie        0            4.0        20.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3   Digital Wallet  Takeaway       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card  Takeaway       2023-03-31
# 6   Digital Wallet  Takeaway       2023-10-06
# 7             Cash  Takeaway       2023-10-28
# 8   Digital Wallet  Takeaway       2023-07-28
# 9   Digital Wallet  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 12            Cash  In-store       2023-05-03
# 13  Digital Wallet  Takeaway       2023-06-01
# 14  Digital Wallet  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16  Digital Wallet  Takeaway       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash  Takeaway       2023-03-25
# 19            Cash  Takeaway       2023-01-15
# 20            Cash  In-store       2023-04-04

# %% [markdown]
# ### Converting the data types

# %%
cafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9540 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    9540 non-null   object
#  1   Item              9540 non-null   object
#  2   Quantity          9540 non-null   object
#  3   Price Per Unit    9540 non-null   object
#  4   Total Spent       9540 non-null   object
#  5   Payment Method    9540 non-null   object
#  6   Location          9540 non-null   object
#  7   Transaction Date  9540 non-null   object
# dtypes: object(8)
# memory usage: 670.8+ KB

# %% [markdown]
# ## The following columns are to be changed: 'Quantity', 'Price Per Unit', and 'Total Spent'.

# %%
# convert the Quantity column to integer
cafe['Quantity'] = cafe['Quantity'].astype('int64')

# convert the Price Per Unit to float
cafe['Price Per Unit'] = cafe['Price Per Unit'].astype('float64')

# convert the Total Spent to float
cafe['Total Spent'] = cafe['Total Spent'].astype('float64')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10232\862286827.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cafe['Quantity'] = cafe['Quantity'].astype('int64')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10232\862286827.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cafe['Price Per Unit'] = cafe['Price Per Unit'].astype('float64')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10232\862286827.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cafe['Total Spent'] = cafe['Total Spent'].astype('float64')

# %% [markdown]
# ### Convert the Transaction date data type to datetime

# %%
#convert the Transaction date to datetime
cafe['Transaction Date'] = pd.to_datetime(cafe['Transaction Date'], format = '%Y-%m-%d')
cafe.head(20)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10232\2563715573.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cafe['Transaction Date'] = pd.to_datetime(cafe['Transaction Date'], format = '%Y-%m-%d')
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee         2             2.0          4.0
# 1     TXN_4977031      Cake         4             3.0         12.0
# 2     TXN_4271903    Cookie         4             1.0          0.0
# 3     TXN_7034554     Salad         2             5.0         10.0
# 4     TXN_3160411    Coffee         2             2.0          4.0
# 5     TXN_2602893  Smoothie         5             4.0         20.0
# 6     TXN_4433211     Juice         3             3.0          9.0
# 7     TXN_6699534  Sandwich         4             4.0         16.0
# 8     TXN_4717867     Juice         5             3.0         15.0
# 9     TXN_2064365  Sandwich         5             4.0         20.0
# 10    TXN_2548360     Salad         5             5.0         25.0
# 12    TXN_7619095  Sandwich         2             4.0          8.0
# 13    TXN_9437049    Cookie         5             1.0          5.0
# 14    TXN_8915701     Juice         2             1.5          3.0
# 15    TXN_2847255     Salad         3             5.0         15.0
# 16    TXN_3765707  Sandwich         1             4.0          4.0
# 17    TXN_6769710     Juice         2             3.0          6.0
# 18    TXN_8876618      Cake         5             3.0         15.0
# 19    TXN_3709394     Juice         4             3.0         12.0
# 20    TXN_3522028  Smoothie         0             4.0         20.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3   Digital Wallet  Takeaway       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card  Takeaway       2023-03-31
# 6   Digital Wallet  Takeaway       2023-10-06
# 7             Cash  Takeaway       2023-10-28
# 8   Digital Wallet  Takeaway       2023-07-28
# 9   Digital Wallet  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 12            Cash  In-store       2023-05-03
# 13  Digital Wallet  Takeaway       2023-06-01
# 14  Digital Wallet  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16  Digital Wallet  Takeaway       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash  Takeaway       2023-03-25
# 19            Cash  Takeaway       2023-01-15
# 20            Cash  In-store       2023-04-04

# %%
cafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9540 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    9540 non-null   object
#  1   Item              9540 non-null   object
#  2   Quantity          9540 non-null   int64
#  3   Price Per Unit    9540 non-null   float64
#  4   Total Spent       9540 non-null   float64
#  5   Payment Method    9540 non-null   object
#  6   Location          9540 non-null   object
#  7   Transaction Date  9540 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 670.8+ KB

# %% [markdown]
# ### Replacing the zero's in the following columns with the mean of the column; 'Quantity', and 'Price Per Unit'

# %%
cafe[(cafe['Quantity'] > 0) & (cafe['Price Per Unit'] > 0)].describe()
# Out:
#           Quantity  Price Per Unit        Sales               Transaction Date
# count  8596.000000     8596.000000  8596.000000                           8596
# mean      3.020358        2.951547     8.921650  2023-07-01 20:24:04.020474880
# min       1.000000        1.000000     1.000000            2023-01-01 00:00:00
# 25%       2.000000        2.000000     4.000000            2023-04-01 00:00:00
# 50%       3.000000        3.000000     8.000000            2023-07-02 00:00:00
# 75%       4.000000        4.000000    12.000000            2023-10-01 00:00:00
# max       5.000000        5.000000    25.000000            2023-12-31 00:00:00
# std       1.417477        1.276884     5.988538                            NaN

# %%
# Replacing the zero's with the mean

cafe[['Quantity','Price Per Unit']] = cafe[['Quantity','Price Per Unit']].replace(0,3)
cafe.head(20)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Sales  Payment Method  \
# 0     TXN_1961373    Coffee         2             2.0    4.0     Credit Card
# 1     TXN_4977031      Cake         4             3.0   12.0            Cash
# 2     TXN_4271903    Cookie         4             1.0    4.0     Credit Card
# 3     TXN_7034554     Salad         2             5.0   10.0  Digital Wallet
# 4     TXN_3160411    Coffee         2             2.0    4.0  Digital Wallet
# 5     TXN_2602893  Smoothie         5             4.0   20.0     Credit Card
# 6     TXN_4433211     Juice         3             3.0    9.0  Digital Wallet
# 7     TXN_6699534  Sandwich         4             4.0   16.0            Cash
# 8     TXN_4717867     Juice         5             3.0   15.0  Digital Wallet
# 9     TXN_2064365  Sandwich         5             4.0   20.0  Digital Wallet
# 10    TXN_2548360     Salad         5             5.0   25.0            Cash
# 11    TXN_7619095  Sandwich         2             4.0    8.0            Cash
# 12    TXN_9437049    Cookie         5             1.0    5.0  Digital Wallet
# 13    TXN_8915701     Juice         2             1.5    3.0  Digital Wallet
# 14    TXN_2847255     Salad         3             5.0   15.0     Credit Card
# 15    TXN_3765707  Sandwich         1             4.0    4.0  Digital Wallet
# 16    TXN_6769710     Juice         2             3.0    6.0            Cash
# 17    TXN_8876618      Cake         5             3.0   15.0            Cash
# 18    TXN_3709394     Juice         4             3.0   12.0            Cash
# 19    TXN_3522028  Smoothie         3             4.0    0.0            Cash
#
#     Location Transaction Date
# 0   Takeaway       2023-09-08
# 1   In-store       2023-05-16
# 2   In-store       2023-07-19
# 3   Takeaway       2023-04-27
# 4   In-store       2023-06-11
# 5   Takeaway       2023-03-31
# 6   Takeaway       2023-10-06
# 7   Takeaway       2023-10-28
# 8   Takeaway       2023-07-28
# 9   In-store       2023-12-31
# 10  Takeaway       2023-11-07
# 11  In-store       2023-05-03
# 12  Takeaway       2023-06-01
# 13  In-store       2023-03-21
# 14  In-store       2023-11-15
# 15  Takeaway       2023-06-10
# 16  In-store       2023-02-24
# 17  Takeaway       2023-03-25
# 18  Takeaway       2023-01-15
# 19  In-store       2023-04-04

# %% [markdown]
# ## Renaming the Total Spent column to Sales and Recalculating the column

# %%
cafe = cafe.rename(columns = {'Total Spent': 'Sales'})
cafe.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Sales  Payment Method  \
# 0    TXN_1961373  Coffee         2             2.0    4.0     Credit Card
# 1    TXN_4977031    Cake         4             3.0   12.0            Cash
# 2    TXN_4271903  Cookie         4             1.0    0.0     Credit Card
# 3    TXN_7034554   Salad         2             5.0   10.0  Digital Wallet
# 4    TXN_3160411  Coffee         2             2.0    4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3  Takeaway       2023-04-27
# 4  In-store       2023-06-11

# %%
#Recalculating the Sales
cafe['Sales'] = cafe['Quantity'] * cafe['Price Per Unit']

cafe.head(10)
# Out:
#   Transaction ID      Item  Quantity  Price Per Unit  Sales  Payment Method  \
# 0    TXN_1961373    Coffee         2             2.0    4.0     Credit Card
# 1    TXN_4977031      Cake         4             3.0   12.0            Cash
# 2    TXN_4271903    Cookie         4             1.0    4.0     Credit Card
# 3    TXN_7034554     Salad         2             5.0   10.0  Digital Wallet
# 4    TXN_3160411    Coffee         2             2.0    4.0  Digital Wallet
# 5    TXN_2602893  Smoothie         5             4.0   20.0     Credit Card
# 6    TXN_4433211     Juice         3             3.0    9.0  Digital Wallet
# 7    TXN_6699534  Sandwich         4             4.0   16.0            Cash
# 8    TXN_4717867     Juice         5             3.0   15.0  Digital Wallet
# 9    TXN_2064365  Sandwich         5             4.0   20.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3  Takeaway       2023-04-27
# 4  In-store       2023-06-11
# 5  Takeaway       2023-03-31
# 6  Takeaway       2023-10-06
# 7  Takeaway       2023-10-28
# 8  Takeaway       2023-07-28
# 9  In-store       2023-12-31

# %%
#Renaming the index
cafe = cafe.reset_index(drop = True)

cafe.head(30)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Sales  Payment Method  \
# 0     TXN_1961373    Coffee         2             2.0    4.0     Credit Card
# 1     TXN_4977031      Cake         4             3.0   12.0            Cash
# 2     TXN_4271903    Cookie         4             1.0    4.0     Credit Card
# 3     TXN_7034554     Salad         2             5.0   10.0  Digital Wallet
# 4     TXN_3160411    Coffee         2             2.0    4.0  Digital Wallet
# 5     TXN_2602893  Smoothie         5             4.0   20.0     Credit Card
# 6     TXN_4433211     Juice         3             3.0    9.0  Digital Wallet
# 7     TXN_6699534  Sandwich         4             4.0   16.0            Cash
# 8     TXN_4717867     Juice         5             3.0   15.0  Digital Wallet
# 9     TXN_2064365  Sandwich         5             4.0   20.0  Digital Wallet
# 10    TXN_2548360     Salad         5             5.0   25.0            Cash
# 11    TXN_7619095  Sandwich         2             4.0    8.0            Cash
# 12    TXN_9437049    Cookie         5             1.0    5.0  Digital Wallet
# 13    TXN_8915701     Juice         2             1.5    3.0  Digital Wallet
# 14    TXN_2847255     Salad         3             5.0   15.0     Credit Card
# 15    TXN_3765707  Sandwich         1             4.0    4.0  Digital Wallet
# 16    TXN_6769710     Juice         2             3.0    6.0            Cash
# 17    TXN_8876618      Cake         5             3.0   15.0            Cash
# 18    TXN_3709394     Juice         4             3.0   12.0            Cash
# 19    TXN_3522028  Smoothie         3             4.0   12.0            Cash
# 20    TXN_3567645  Smoothie         4             4.0   16.0     Credit Card
# 21    TXN_5132361  Sandwich         3             4.0   12.0  Digital Wallet
# 22    TXN_2616390  Sandwich         2             4.0    8.0  Digital Wallet
# 23    TXN_9400181  Sandwich         5             4.0   20.0            Cash
# 24    TXN_7958992  Smoothie         3             4.0   12.0  Digital Wallet
# 25    TXN_5183041    Cookie         5             1.0    5.0     Credit Card
# 26    TXN_5695074     Juice         4             3.0   12.0     Credit Card
# 27    TXN_8467949  Smoothie         5             4.0   20.0     Credit Card
# 28    TXN_1736287     Juice         5             2.0   10.0  Digital Wallet
# 29    TXN_8927252     Juice         2             1.0    2.0     Credit Card
#
#     Location Transaction Date
# 0   Takeaway       2023-09-08
# 1   In-store       2023-05-16
# 2   In-store       2023-07-19
# 3   Takeaway       2023-04-27
# 4   In-store       2023-06-11
# 5   Takeaway       2023-03-31
# 6   Takeaway       2023-10-06
# 7   Takeaway       2023-10-28
# 8   Takeaway       2023-07-28
# 9   In-store       2023-12-31
# 10  Takeaway       2023-11-07
# 11  In-store       2023-05-03
# 12  Takeaway       2023-06-01
# 13  In-store       2023-03-21
# 14  In-store       2023-11-15
# 15  Takeaway       2023-06-10
# 16  In-store       2023-02-24
# 17  Takeaway       2023-03-25
# 18  Takeaway       2023-01-15
# 19  In-store       2023-04-04
# 20  Takeaway       2023-03-30
# 21  Takeaway       2023-12-01
# 22  Takeaway       2023-09-18
# 23  In-store       2023-06-03
# 24  Takeaway       2023-12-13
# 25  In-store       2023-04-20
# 26  Takeaway       2023-04-10
# 27  Takeaway       2023-03-11
# 28  Takeaway       2023-06-02
# 29  Takeaway       2023-11-06

# %% [markdown]
# ## Save the cleaned data into csv file.

# %%
cafe.to_csv('cafe_Cleaned_data.csv')

# %%
cafe_data = pd.read_csv('cafe_Cleaned_data.csv')

cafe_data.head(30)
# Out:
#     Unnamed: 0 Transaction ID      Item  Quantity  Price Per Unit  Sales  \
# 0            0    TXN_1961373    Coffee         2             2.0    4.0
# 1            1    TXN_4977031      Cake         4             3.0   12.0
# 2            2    TXN_4271903    Cookie         4             1.0    4.0
# 3            3    TXN_7034554     Salad         2             5.0   10.0
# 4            4    TXN_3160411    Coffee         2             2.0    4.0
# 5            5    TXN_2602893  Smoothie         5             4.0   20.0
# 6            6    TXN_4433211     Juice         3             3.0    9.0
# 7            7    TXN_6699534  Sandwich         4             4.0   16.0
# 8            8    TXN_4717867     Juice         5             3.0   15.0
# 9            9    TXN_2064365  Sandwich         5             4.0   20.0
# 10          10    TXN_2548360     Salad         5             5.0   25.0
# 11          11    TXN_7619095  Sandwich         2             4.0    8.0
# 12          12    TXN_9437049    Cookie         5             1.0    5.0
# 13          13    TXN_8915701     Juice         2             1.5    3.0
# 14          14    TXN_2847255     Salad         3             5.0   15.0
# 15          15    TXN_3765707  Sandwich         1             4.0    4.0
# 16          16    TXN_6769710     Juice         2             3.0    6.0
# 17          17    TXN_8876618      Cake         5             3.0   15.0
# 18          18    TXN_3709394     Juice         4             3.0   12.0
# 19          19    TXN_3522028  Smoothie         3             4.0   12.0
# 20          20    TXN_3567645  Smoothie         4             4.0   16.0
# 21          21    TXN_5132361  Sandwich         3             4.0   12.0
# 22          22    TXN_2616390  Sandwich         2             4.0    8.0
# 23          23    TXN_9400181  Sandwich         5             4.0   20.0
# 24          24    TXN_7958992  Smoothie         3             4.0   12.0
# 25          25    TXN_5183041    Cookie         5             1.0    5.0
# 26          26    TXN_5695074     Juice         4             3.0   12.0
# 27          27    TXN_8467949  Smoothie         5             4.0   20.0
# 28          28    TXN_1736287     Juice         5             2.0   10.0
# 29          29    TXN_8927252     Juice         2             1.0    2.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3   Digital Wallet  Takeaway       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card  Takeaway       2023-03-31
# 6   Digital Wallet  Takeaway       2023-10-06
# 7             Cash  Takeaway       2023-10-28
# 8   Digital Wallet  Takeaway       2023-07-28
# 9   Digital Wallet  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11            Cash  In-store       2023-05-03
# 12  Digital Wallet  Takeaway       2023-06-01
# 13  Digital Wallet  In-store       2023-03-21
# 14     Credit Card  In-store       2023-11-15
# 15  Digital Wallet  Takeaway       2023-06-10
# 16            Cash  In-store       2023-02-24
# 17            Cash  Takeaway       2023-03-25
# 18            Cash  Takeaway       2023-01-15
# 19            Cash  In-store       2023-04-04
# 20     Credit Card  Takeaway       2023-03-30
# 21  Digital Wallet  Takeaway       2023-12-01
# 22  Digital Wallet  Takeaway       2023-09-18
# 23            Cash  In-store       2023-06-03
# 24  Digital Wallet  Takeaway       2023-12-13
# 25     Credit Card  In-store       2023-04-20
# 26     Credit Card  Takeaway       2023-04-10
# 27     Credit Card  Takeaway       2023-03-11
# 28  Digital Wallet  Takeaway       2023-06-02
# 29     Credit Card  Takeaway       2023-11-06
